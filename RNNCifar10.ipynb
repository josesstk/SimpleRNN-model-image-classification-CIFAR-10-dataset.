# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from tensorflow.keras.utils import to_categorical

# %%
# Load the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize the input images
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Convert class vectors to binary class matrices (one-hot encoding)
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Reshape images to be treated as sequences:
# Each image is 32x32x3 => reshape to (32 time steps, 96 features)
x_train_seq = x_train.reshape(-1, 32, 96)
x_test_seq = x_test.reshape(-1, 32, 96)

# %%
model = Sequential([
    SimpleRNN(64, input_shape=(32, 96), return_sequences=False),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

model.summary()
# Out:
# C:\Users\TK\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │        10,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# ...

# %%
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Train the model
history = model.fit(
    x_train_seq, y_train,
    epochs=10,
    batch_size=64,
    validation_split=0.2,
    verbose=2
)
# Out:
# Epoch 1/10
# 625/625 - 11s - 17ms/step - accuracy: 0.2536 - loss: 2.0216 - val_accuracy: 0.2602 - val_loss: 1.9985
# Epoch 2/10
# 625/625 - 5s - 8ms/step - accuracy: 0.3013 - loss: 1.9008 - val_accuracy: 0.2867 - val_loss: 1.9312
# Epoch 3/10
# 625/625 - 5s - 8ms/step - accuracy: 0.3173 - loss: 1.8531 - val_accuracy: 0.3113 - val_loss: 1.8933
# Epoch 4/10
# 625/625 - 5s - 8ms/step - accuracy: 0.3299 - loss: 1.8339 - val_accuracy: 0.3350 - val_loss: 1.8446
# Epoch 5/10
# 625/625 - 4s - 7ms/step - accuracy: 0.3354 - loss: 1.8241 - val_accuracy: 0.3426 - val_loss: 1.8053
# Epoch 6/10
# 625/625 - 5s - 8ms/step - accuracy: 0.3273 - loss: 1.8322 - val_accuracy: 0.3529 - val_loss: 1.7851
# Epoch 7/10
# 625/625 - 6s - 9ms/step - accuracy: 0.3512 - loss: 1.7706 - val_accuracy: 0.3563 - val_loss: 1.7678
# Epoch 8/10
# 625/625 - 5s - 8ms/step - accuracy: 0.3546 - loss: 1.7723 - val_accuracy: 0.3559 - val_loss: 1.7592
# Epoch 9/10
# ...

# %%
test_loss, test_accuracy = model.evaluate(x_test_seq, y_test, verbose=2)
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 313/313 - 1s - 5ms/step - accuracy: 0.3699 - loss: 1.7375
# Test Accuracy: 0.3699
